# %%
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
test_data = pd.read_csv("test.csv")
train_data = pd.read_csv("train.csv")
combine = [train_data, test_data]
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_data.describe(include=['O'])
# Out:
#                                   Name   Sex Ticket Cabin Embarked
# count                              891   891    891   204      889
# unique                             891     2    681   147        3
# top     Ostby, Mr. Engelhart Cornelius  male   1601    G6        S
# freq                                 1   577      7     4      644

# %%
cor = train_data.corr()
sns.heatmap(cor, vmax=.8, square=True, annot = True);

# %%
cols = train_data.columns
dis_cols = cols.drop(['Survived', 'PassengerId','Name','Age','Ticket','Fare','Cabin'])
for x in dis_cols:
    ana = train_data[[x, 'Survived']].groupby(x).mean().sort_values(by='Survived',ascending=False)
    print(ana)
    print("_"*10)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363
# __________
#         Survived
# Sex
# female  0.742038
# male    0.188908
# __________
#        Survived
# SibSp
# 1      0.535885
# 2      0.464286
# 0      0.345395
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000
# __________
#        Survived
# Parch
# 3      0.600000
# 1      0.550847
# 2      0.500000
# 0      0.343658
# 5      0.200000
# 4      0.000000
# 6      0.000000
# __________
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957
# __________

# %%
import seaborn as sns
g = sns.FacetGrid(train_data, col = "Survived", size = 10)
g.map(plt.hist, 'Age', bins = 50)
plt.xticks(np.arange(0,81, step = 5))
plt.figure(figsize = (14,6))
g = sns.FacetGrid(train_data, col = "Survived", size = 10)
g.map(plt.hist, 'Fare', bins = 20)
plt.xticks(np.arange(0,520, step = 50))
# Out:
# D:\anaconda\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ([<matplotlib.axis.XTick at 0x1c8aec9c8c8>,
#   <matplotlib.axis.XTick at 0x1c8aec99c88>,
#   <matplotlib.axis.XTick at 0x1c8af0e3ec8>,
#   <matplotlib.axis.XTick at 0x1c8af0f9608>,
#   <matplotlib.axis.XTick at 0x1c8af0f9e48>,
#   <matplotlib.axis.XTick at 0x1c8af0fb7c8>,
#   <matplotlib.axis.XTick at 0x1c8af175808>,
#   <matplotlib.axis.XTick at 0x1c8af1809c8>,
#   <matplotlib.axis.XTick at 0x1c8aec60b08>,
#   <matplotlib.axis.XTick at 0x1c8af10bfc8>,
#   <matplotlib.axis.XTick at 0x1c8af17c588>],
#  <a list of 11 Text xticklabel objects>)

# %%
train_data.plot.scatter(x='Pclass', y='Fare', c='Survived', colormap='viridis')

# %%
for df in combine:
    df['TicketTitle'] = df.Ticket.str.replace('(.* +?)','')
    df['CabinClass'] = df.Cabin.str.extract('([a-zA-Z])',expand = False)

cv =  train_data['TicketTitle'].value_counts()
title = cv[cv==3].index.tolist()
for x in title:
    print(train_data.groupby('TicketTitle').get_group(x))
    print('-'*100)
# Out:
#      PassengerId  Survived  Pclass  \
# 237          238         1       2
# 637          638         0       2
# 801          802         1       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 237             Collyer, Miss. Marjorie "Lottie"  female   8.0      0      2
# 637                          Collyer, Mr. Harvey    male  31.0      1      1
# 801  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1      1
#
#          Ticket   Fare Cabin Embarked TicketTitle CabinClass
# 237  C.A. 31921  26.25   NaN        S       31921        NaN
# 637  C.A. 31921  26.25   NaN        S       31921        NaN
# 801  C.A. 31921  26.25   NaN        S       31921        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                  Name  \
# 275          276         1       1     Andrews, Miss. Kornelia Theodosia
# 627          628         1       1         Longley, Miss. Gretchen Fiske
# 765          766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
#
#         Sex   Age  SibSp  Parch Ticket     Fare Cabin Embarked TicketTitle  \
# 275  female  63.0      1      0  13502  77.9583    D7        S       13502
# 627  female  21.0      0      0  13502  77.9583    D9        S       13502
# 765  female  51.0      1      0  13502  77.9583   D11        S       13502
#
#     CabinClass
# 275          D
# 627          D
# 765          D
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     TicketTitle CabinClass
# 258       17755        NaN
# 679       17755          B
# 737       17755          B
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 596          597         1       2         Leitch, Miss. Jessie Wills  female
# 720          721         1       2  Harper, Miss. Annie Jessie "Nina"  female
# 848          849         0       2                  Harper, Rev. John    male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked TicketTitle CabinClass
# 596   NaN      0      0  248727  33.0   NaN        S      248727        NaN
# 720   6.0      0      1  248727  33.0   NaN        S      248727        NaN
# 848  28.0      0      1  248727  33.0   NaN        S      248727        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 215          216         1       1     Newell, Miss. Madeleine  female  31.0
# 393          394         1       1      Newell, Miss. Marjorie  female  23.0
# 659          660         0       1  Newell, Mr. Arthur Webster    male  58.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked TicketTitle CabinClass
# 215      1      0  35273  113.275   D36        C       35273          D
# 393      1      0  35273  113.275   D36        C       35273          D
# 659      0      2  35273  113.275   D48        C       35273          D
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 172          173         1       3
# 869          870         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 172                       Johnson, Miss. Eleanor Ileen  female   1.0      1
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
#
#      Parch  Ticket     Fare Cabin Embarked TicketTitle CabinClass
# 8        2  347742  11.1333   NaN        S      347742        NaN
# 172      1  347742  11.1333   NaN        S      347742        NaN
# 869      1  347742  11.1333   NaN        S      347742        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                 Name     Sex  Age  SibSp  \
# 109          110         1       3  Moran, Miss. Bertha  female  NaN      1
# 517          518         0       3    Ryan, Mr. Patrick    male  NaN      0
# 768          769         0       3  Moran, Mr. Daniel J    male  NaN      1
#
#      Parch  Ticket   Fare Cabin Embarked TicketTitle CabinClass
# 109      0  371110  24.15   NaN        Q      371110        NaN
# 517      0  371110  24.15   NaN        Q      371110        NaN
# 768      0  371110  24.15   NaN        Q      371110        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 165          166         1       3
# 328          329         1       3
# 548          549         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 165  Goldsmith, Master. Frank John William "Frankie"    male   9.0      0
# 328   Goldsmith, Mrs. Frank John (Emily Alice Brown)  female  31.0      1
# 548                        Goldsmith, Mr. Frank John    male  33.0      1
#
#      Parch  Ticket    Fare Cabin Embarked TicketTitle CabinClass
# 165      2  363291  20.525   NaN        S      363291        NaN
# 328      1  363291  20.525   NaN        S      363291        NaN
# 548      1  363291  20.525   NaN        S      363291        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                     Name  \
# 58            59         1       2             West, Miss. Constance Mirium
# 450          451         0       2                    West, Mr. Edwy Arthur
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked TicketTitle  \
# 58   female   5.0      1      2  C.A. 34651  27.75   NaN        S       34651
# 450    male  36.0      1      2  C.A. 34651  27.75   NaN        S       34651
# 472  female  33.0      1      2  C.A. 34651  27.75   NaN        S       34651
#
#     CabinClass
# 58         NaN
# 450        NaN
# 472        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 269          270         1       1    Bissette, Miss. Amelia  female  35.0
# 325          326         1       1  Young, Miss. Marie Grice  female  36.0
# 373          374         0       1       Ringhini, Mr. Sante    male  22.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked TicketTitle CabinClass
# 269      0      0  PC 17760  135.6333   C99        S       17760          C
# 325      0      0  PC 17760  135.6333   C32        C       17760          C
# 373      0      0  PC 17760  135.6333   NaN        C       17760        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                      Name  \
# 148          149         0       2  Navratil, Mr. Michel ("Louis M Hoffman")
# 193          194         1       2                Navratil, Master. Michel M
# 340          341         1       2            Navratil, Master. Edmond Roger
#
#       Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked TicketTitle  \
# 148  male  36.5      0      2  230080  26.0    F2        S      230080
# 193  male   3.0      1      1  230080  26.0    F2        S      230080
# 340  male   2.0      1      1  230080  26.0    F2        S      230080
#
#     CabinClass
# 148          F
# 193          F
# 340          F
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                       Name  \
# 572          573         1       1           Flynn, Mr. John Irwin ("Irving")
# 690          691         1       1                    Dick, Mr. Albert Adrian
# 781          782         1       1  Dick, Mrs. Albert Adrian (Vera Gillespie)
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked TicketTitle  \
# 572    male  36.0      0      0  PC 17474  26.3875   E25        S       17474
# 690    male  31.0      1      0     17474  57.0000   B20        S       17474
# 781  female  17.0      1      0     17474  57.0000   B20        S       17474
#
#     CabinClass
# 572          E
# 690          B
# 781          B
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 689          690         1       1
# 730          731         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 689                  Madill, Miss. Georgette Alexandra  female  15.0      0
# 730                      Allen, Miss. Elisabeth Walton  female  29.0      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
#
#      Parch Ticket      Fare Cabin Embarked TicketTitle CabinClass
# 689      1  24160  211.3375    B5        S       24160          B
# 730      0  24160  211.3375    B5        S       24160          B
# 779      1  24160  211.3375    B3        S       24160          B
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                   Name  \
# 407          408         1       2         Richards, Master. William Rowe
# 437          438         1       2  Richards, Mrs. Sidney (Emily Hocking)
# 831          832         1       2        Richards, Master. George Sibley
#
#         Sex    Age  SibSp  Parch Ticket   Fare Cabin Embarked TicketTitle  \
# 407    male   3.00      1      1  29106  18.75   NaN        S       29106
# 437  female  24.00      2      3  29106  18.75   NaN        S       29106
# 831    male   0.83      1      1  29106  18.75   NaN        S       29106
#
#     CabinClass
# 407        NaN
# 437        NaN
# 831        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 43            44         1       2
# 608          609         1       2
# 685          686         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female  22.0      1
# 685             Laroche, Mr. Joseph Philippe Lemercier    male  25.0      1
#
#      Parch         Ticket     Fare Cabin Embarked TicketTitle CabinClass
# 43       2  SC/Paris 2123  41.5792   NaN        C        2123        NaN
# 608      2  SC/Paris 2123  41.5792   NaN        C        2123        NaN
# 685      2  SC/Paris 2123  41.5792   NaN        C        2123        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 419          420         0       3
# 595          596         0       3
# 799          800         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 419                          Van Impe, Miss. Catharina  female  10.0      0
# 595                        Van Impe, Mr. Jean Baptiste    male  36.0      1
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
#
#      Parch  Ticket   Fare Cabin Embarked TicketTitle CabinClass
# 419      2  345773  24.15   NaN        S      345773        NaN
# 595      1  345773  24.15   NaN        S      345773        NaN
# 799      1  345773  24.15   NaN        S      345773        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 268          269         1       1
# 332          333         0       1
# 609          610         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 268  Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 332                      Graham, Mr. George Edward    male  38.0      0
# 609                      Shutes, Miss. Elizabeth W  female  40.0      0
#
#      Parch    Ticket      Fare Cabin Embarked TicketTitle CabinClass
# 268      1  PC 17582  153.4625  C125        S       17582          C
# 332      1  PC 17582  153.4625   C91        S       17582          C
# 609      0  PC 17582  153.4625  C125        S       17582          C
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 314          315         0       2
# 440          441         1       2
# 535          536         1       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 314                           Hart, Mr. Benjamin    male  43.0      1      1
# 440  Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female  45.0      1      1
# 535                       Hart, Miss. Eva Miriam  female   7.0      0      2
#
#            Ticket   Fare Cabin Embarked TicketTitle CabinClass
# 314  F.C.C. 13529  26.25   NaN        S       13529        NaN
# 440  F.C.C. 13529  26.25   NaN        S       13529        NaN
# 535  F.C.C. 13529  26.25   NaN        S       13529        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass  \
# 257          258         1       1
# 504          505         1       1
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked TicketTitle CabinClass
# 257      0  110152  86.5   B77        S      110152          B
# 504      0  110152  86.5   B79        S      110152          B
# 759      0  110152  86.5   B77        S      110152          B
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 277          278         0       2     Parkes, Mr. Francis "Frank"  male  NaN
# 413          414         0       2  Cunningham, Mr. Alfred Fleming  male  NaN
# 466          467         0       2           Campbell, Mr. William  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked TicketTitle CabinClass
# 277      0      0  239853   0.0   NaN        S      239853        NaN
# 413      0      0  239853   0.0   NaN        S      239853        NaN
# 466      0      0  239853   0.0   NaN        S      239853        NaN
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                    Name  \
# 262          263         0       1                       Taussig, Mr. Emil
# 558          559         1       1  Taussig, Mrs. Emil (Tillie Mandelbaum)
# 585          586         1       1                     Taussig, Miss. Ruth
#
#         Sex   Age  SibSp  Parch  Ticket   Fare Cabin Embarked TicketTitle  \
# 262    male  52.0      1      1  110413  79.65   E67        S      110413
# 558  female  39.0      1      1  110413  79.65   E67        S      110413
# 585  female  18.0      0      2  110413  79.65   E68        S      110413
#
#     CabinClass
# 262          E
# 558          E
# 585          E
# ----------------------------------------------------------------------------------------------------
#      PassengerId  Survived  Pclass                                      Name  \
# 52            53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 645          646         1       1                 Harper, Mr. Henry Sleeper
# 681          682         1       1                        Hassab, Mr. Hammad
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked TicketTitle  \
# 52   female  49.0      1      0  PC 17572  76.7292   D33        C       17572
# 645    male  48.0      1      0  PC 17572  76.7292   D33        C       17572
# 681    male  27.0      0      0  PC 17572  76.7292   D49        C       17572
#
#     CabinClass
# 52           D
# 645          D
# 681          D
# ----------------------------------------------------------------------------------------------------

# %%
train_data = train_data.drop(['Cabin','Ticket','CabinClass'], axis = 1)
test_data = test_data.drop(['Cabin', 'Ticket', 'CabinClass'], axis = 1)
combine = [train_data, test_data]
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked TicketTitle
# 0      0   7.2500        S       21171
# 1      0  71.2833        C       17599
# 2      0   7.9250        S     3101282
# 3      0  53.1000        S      113803
# 4      0   8.0500        S      373450

# %%
from sklearn.impute import SimpleImputer
median_imputer = SimpleImputer(strategy = 'median')
mostfreq_imputer = SimpleImputer(strategy = 'most_frequent')

# %%
train_data['Age'] = median_imputer.fit_transform(train_data[['Age']])
test_data['Age'] = median_imputer.transform(test_data[['Age']])
train_data['Fare'] = median_imputer.fit_transform(train_data[['Fare']])
test_data['Fare'] = median_imputer.transform(test_data[['Fare']])
train_data['Embarked'] = mostfreq_imputer.fit_transform(train_data[['Embarked']])
test_data['Embarked'] = mostfreq_imputer.transform(test_data[['Embarked']])

# %%
for df in combine:
    df['family'] = df['SibSp']+df['Parch']
train_data = train_data.drop(['SibSp','Parch'], axis = 1)
test_data = test_data.drop(['SibSp','Parch'],axis=1)
combine = [train_data, test_data]

# %%
train_data[['family', 'Survived']].groupby('family').mean().sort_values(by='Survived',ascending=False)
# Out:
#         Survived
# family
# 3       0.724138
# 2       0.578431
# 1       0.552795
# 6       0.333333
# 0       0.303538
# 4       0.200000
# 5       0.136364
# 7       0.000000
# 10      0.000000

# %%
for df in combine:
    df['Alone'] = 0
    df.loc[df['family']==0, 'Alone']=1
train_data = train_data.drop(['family'],axis = 1)
test_data = test_data.drop(['family'],axis = 1)
combine = [train_data, test_data]
train_data[['Alone', 'Survived']].groupby('Alone').mean().sort_values(by='Survived',ascending=False)
# Out:
#        Survived
# Alone
# 0      0.505650
# 1      0.303538

# %%
for df in combine:
    df['Title'] = df.Name.str.extract('([A-Za-z]+)\.',expand = False)

pd.crosstab(train_data['Title'], train_data['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for df in combine:
    df['Title'] = df['Title'].replace(['Capt','Col','Countess','Don','Dr','Jonkheer','Lady','Major','Mlle','Mme','Ms','Rev','Sir'],'Others')
train_data[['Title','Survived']].groupby(['Title']).mean()
# Out:
#         Survived
# Title
# Master  0.575000
# Miss    0.697802
# Mr      0.156673
# Mrs     0.792000
# Others  0.444444

# %%
train_data = train_data.drop(['Name'],axis=1)
test_data = test_data.drop(['Name'],axis = 1)
combine = [train_data,test_data]
for df in combine:
    df['Sex'] = df['Sex'].map({'female':0,'male':1}).astype(int)

# %%
train_data['TicketTitle'] = train_data['TicketTitle'].replace('LINE','0').astype(int)
test_data['TicketTitle'] = test_data['TicketTitle'].replace('LINE','0').astype(int)
combine = [train_data,test_data]

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(handle_unknown = 'ignore', sparse = False)
features = ['Embarked', 'Title']
OH_train_cols = pd.DataFrame(encoder.fit_transform(train_data[features]))
OH_test_cols = pd.DataFrame(encoder.transform(test_data[features]))
OH_train_cols.index = train_data.index
OH_test_cols.index = test_data.index
train_data = train_data.drop(features, axis = 1)
test_data = test_data.drop(features, axis = 1)
train_data = pd.concat([train_data, OH_train_cols], axis = 1)
test_data = pd.concat([test_data, OH_test_cols], axis = 1)

# %%
from sklearn.model_selection import GridSearchCV
X = train_data.drop(['PassengerId','Survived'], axis = 1)
y = train_data['Survived']
X_test = test_data.drop(['PassengerId'], axis =1).copy()

# %%
from sklearn.ensemble import RandomForestClassifier
grid_feature = {'max_features':[10,11,12,13]}
model = RandomForestClassifier(n_estimators = 1000,
                             random_state=1,
                             n_jobs=-1)
grid = GridSearchCV(model, param_grid = grid_feature)
grid.fit(X,y)
print(grid.best_params_)
print(grid.best_score_)
# Out:
# D:\anaconda\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_features': 11}
# 0.8237934904601572

# %%
model = RandomForestClassifier(n_estimators = 1000,
                               max_features = 11,
                             random_state=1,
                             n_jobs=-1)
model.fit(X, y)
y_test = model.predict(X_test)
model.score(X, y)
# Out:
# 0.9977553310886644

# %%
submission = pd.DataFrame({"PassengerId":test_data['PassengerId'],"Survived":y_test})
submission.to_csv('titanic_submission.csv', index = False)
